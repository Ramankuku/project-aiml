# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv('D:\\Projects\\Airline Passenger Satisfaction Dataset\\data\\train.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %%
df.drop(columns=['Arrival Delay in Minutes'], inplace=True)

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
df['satisfaction'] = df['satisfaction'].map({
    'neutral or dissatisfied': 0,
    'satisfied': 1
})

# %%
df.drop(columns=['Unnamed: 0', 'id'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
check_unique_values = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

for i, values in enumerate(check_unique_values):
    print(f'{values}: {df[values].unique()}')
# Out:
# Gender: ['Male' 'Female']
# Customer Type: ['Loyal Customer' 'disloyal Customer']
# Type of Travel: ['Personal Travel' 'Business travel']
# Class: ['Eco Plus' 'Business' 'Eco']
# satisfaction: [0 1]

# %%
count_plot_columns = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

n_cols = 3
n_rows = math.ceil(len(count_plot_columns) / n_cols)

plt.figure(figsize=(5 * n_cols, 5 * n_rows)) 
for i, values in enumerate(count_plot_columns):
    plt.subplot(n_rows, n_cols, i+1)
    ax = sns.countplot(data=df, x=df[values], palette='Set2')
    for p in ax.patches:
        height = p.get_height()
        ax.text(
            x=p.get_x() + p.get_width()/2, 
            y=height*1.02,                 
            s=int(height), 
            ha='center'
    )
plt.tight_layout(w_pad=3, h_pad=4)
plt.plot()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8200\534976919.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x=df[values], palette='Set2')
# C:\Users\PC\AppData\Local\Temp\ipykernel_8200\534976919.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x=df[values], palette='Set2')
# C:\Users\PC\AppData\Local\Temp\ipykernel_8200\534976919.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x=df[values], palette='Set2')
# ...

# %%
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
# Checking the unique values in Inflight wifi service Column, here 0 means Not Applicable and 1-5 means applicable

df['Inflight wifi service'].unique()
# Out:
# array([3, 2, 4, 1, 5, 0], dtype=int64)

# %% [markdown]
# Checking the Correlation between all the columns

# %%
plt.figure(figsize=(15, 8))
corr_all = df.drop(columns=['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']).corr()
sns.heatmap(corr_all, annot=True, cmap='coolwarm')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
corr_columns = ['Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding','Seat comfort','Inflight entertainment','On-board service','Leg room service','Baggage handling','Checkin service','Inflight service', 'Cleanliness']

# %%
plt.figure(figsize=(15, 8))
corr_all = df[corr_columns].corr()
sns.heatmap(corr_all, annot=True, cmap='coolwarm')
plt.tight_layout()
plt.show()

# %% [markdown]
# There are few columns that have high correlation with each other so I make them in single column by taking the mean.

# %%
df['Flight Service'] = df[['Inflight wifi service', 'Food and drink','Seat comfort','Inflight entertainment','Leg room service','Baggage handling','Inflight service','Cleanliness']].mean(axis=1)

# %%
# # corr_columns = ['Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding','Seat comfort','Inflight entertainment','On-board service','Leg room service','Baggage handling','Checkin service','Inflight service', 'Cleanliness']
df['Total_delayed'] = df['Departure Delay in Minutes'] + df['Arrival Delay in Minutes']

# %%
df.drop(columns=['Departure Delay in Minutes','Arrival Delay in Minutes'], inplace=True)

# %%
plt.figure(figsize=(15, 8))
corr_all = df.drop(columns=['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']).corr()
sns.heatmap(corr_all, annot=True, cmap='coolwarm')
plt.tight_layout()
plt.show()

# %%
df.drop(columns=['Inflight wifi service', 'Food and drink','Seat comfort','Inflight entertainment','Leg room service','Baggage handling','Inflight service','Cleanliness'], inplace=True)

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Departure/Arrival time convenient  \
# 0                   460                                  4
# ...

# %%
new_corr = df.drop(columns=['Gender','Customer Type','Age','Type of Travel','Class', 'satisfaction']).corr()
plt.figure(figsize=(10, 6))
sns.heatmap(new_corr, annot=True, cmap='coolwarm')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Departure/Arrival time convenient  \
# 0                   460                                  4
# ...

# %%
df['Online Services'] = df[['Ease of Online booking', 'Online boarding', 'On-board service', 'Checkin service']].mean(axis=1)
df.drop(columns=['Ease of Online booking', 'Online boarding', 'On-board service', 'Checkin service'], inplace=True)

# %%
new_corr = df.drop(columns=['Gender','Customer Type','Age','Type of Travel','Class', 'satisfaction']).corr()
plt.figure(figsize=(10, 6))
sns.heatmap(new_corr, annot=True, cmap='coolwarm')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Departure/Arrival time convenient  Gate location  \
# 0                   460                                  4              1
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X = df.drop(columns=['satisfaction'])
Y = df['satisfaction']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.23, random_state=42)

# %%
ode = OrdinalEncoder()
X_train[['Customer Type', 'Type of Travel', 'Class']] = ode.fit_transform(X_train[['Customer Type', 'Type of Travel', 'Class']])
X_test[['Customer Type', 'Type of Travel', 'Class']] = ode.transform(X_test[['Customer Type', 'Type of Travel', 'Class']])

# %%
le = LabelEncoder()
X_train['Gender'] = le.fit_transform(X_train['Gender'])
X_test['Gender'] = le.fit_transform(X_test['Gender'])

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train[['Flight Distance']] = ss.fit_transform(X_train[['Flight Distance']])
X_test[['Flight Distance']] = ss.transform(X_test[['Flight Distance']])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)

y_pred = tree.predict(X_train)
acc = accuracy_score(y_train, y_pred)
acc
# Out:
# 1.0

# %%
X_train
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 36746        0            0.0   19             1.0    1.0        -0.175300
# 14785        0            1.0   41             0.0    0.0        -0.791492
# 97960        1            0.0   43             0.0    0.0         0.704831
# 8420         1            0.0   37             1.0    1.0        -0.427196
# 23602        0            0.0   24             0.0    0.0         2.619644
# ...        ...            ...  ...             ...    ...              ...
# 54886        1            1.0   39             0.0    1.0        -0.552642
# 76820        1            0.0   17             1.0    1.0        -0.543610
# 103694       1            0.0   46             0.0    1.0         0.009357
# 860          0            0.0   37             0.0    1.0        -0.870774
# 15795        0            0.0   14             1.0    1.0        -0.839663
#
#         Departure/Arrival time convenient  Gate location  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)

importances = rf.feature_importances_

feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
#                               Feature  Importance
# 10                    Online Services    0.194411
# 9                      Flight Service    0.179843
# 4                               Class    0.116651
# 3                      Type of Travel    0.115811
# 5                     Flight Distance    0.110500
# 2                                 Age    0.093646
# 1                       Customer Type    0.054777
# 6   Departure/Arrival time convenient    0.049278
# 8          Departure Delay in Minutes    0.040974
# 7                       Gate location    0.031783
# 0                              Gender    0.012325

# %%
from sklearn.feature_selection import mutual_info_classif
mi = mutual_info_classif(
    X_train, y_train, random_state=42
)

mi_df = pd.DataFrame({
    'Columns':X_train.columns,
    'Importance':mi
}).sort_values(by='Importance', ascending=False)
print(mi_df)
# Out:
#                               Columns  Importance
# 10                    Online Services    0.155486
# 4                               Class    0.136489
# 9                      Flight Service    0.134259
# 3                      Type of Travel    0.116353
# 5                     Flight Distance    0.062824
# 2                                 Age    0.047592
# 1                       Customer Type    0.021588
# 7                       Gate location    0.012827
# 0                              Gender    0.009043
# 6   Departure/Arrival time convenient    0.004934
# 8          Departure Delay in Minutes    0.002890

# %%
X_train['Total_delayed'] = X_train['Total_delayed'].fillna(X_train['Total_delayed'].mean())
X_test['Total_delayed'] = X_test['Total_delayed'].fillna(X_test['Total_delayed'].mean())

# %%
X_train.drop(columns=['Departure/Arrival time convenient', 'Gate location', 'Gender', 'Departure Delay in Minutes'], inplace=True)
X_test.drop(columns=['Departure/Arrival time convenient', 'Gate location', 'Gender', 'Departure Delay in Minutes'], inplace=True)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'max_depth': [3, 5, 7, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5]
}
dt = DecisionTreeClassifier(random_state=42)

grid_search = GridSearchCV(
    estimator=dt,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
best_dt = grid_search.best_estimator_

y_pred = best_dt.predict(X_test)
acc_test = accuracy_score(y_test, y_pred)

print("Test Accuracy:", acc_test)
# Out:
# Test Accuracy: 0.874675705079923

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 0                    A                      3
# 1                    A                      3
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

param_grid = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [5, 10, None],
    'min_samples_split': [2, 5, 10],
}

rf = RandomForestClassifier(random_state=42)

grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Train
grid_search.fit(X_train, y_train)

# Best model
best_rf = grid_search.best_estimator_

# Test prediction
y_pred = best_rf.predict(X_test)
acc_test = accuracy_score(y_test, y_pred)

print("Best Parameters:", grid_search.best_params_)
print("Test Accuracy:", acc_test)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 250}
# Test Accuracy: 0.8787346221441125

# %%
df.drop(columns)
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...
